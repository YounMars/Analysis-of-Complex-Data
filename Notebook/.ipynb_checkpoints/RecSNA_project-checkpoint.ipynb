# %%
import json 
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
def read_chunks(file, cols, chunk_size=500000):
    df = pd.read_json(
        f'/Users/ryounes/Documents/Feup/RecSNA_Project/yelp_academic_dataset_{file}.json', chunksize = chunk_size, lines=True)
    
    chunk_list = [chunk[cols] for chunk in df ]

    return pd.concat(chunk_list, ignore_index = True, join = 'outer', axis = 0)

# %%
business_json_path = '/Users/ryounes/Documents/Feup/RecSNA_Project/yelp_academic_dataset_business.json'
df_b = pd.read_json(business_json_path, lines=True)

# %%
df_u = read_chunks('user', ['user_id','name', 'friends','fans'])

# %%
df_u
# Out:
#                         user_id     name  \
# 0        qVc8ODYU5SZjKXVBgXdI7w   Walker
# 1        j14WgRoU_-2ZE1aw1dXrJg   Daniel
# 2        2WnXYQFK0hXEoTxPtV2zvg    Steph
# 3        SZDeASXq7o05mMNLshsdIA     Gwen
# 4        hA5lMy-EnncsH4JoR-hFGQ    Karen
# ...                         ...      ...
# 1987892  fB3jbHi3m0L2KgGOxBv6uw  Jerrold
# 1987893  68czcr4BxJyMQ9cJBm6C7Q     Jane
# 1987894  1x3KMskYxOuJCjRz70xOqQ  Shomari
# 1987895  ulfGl4tdbrH05xKzh5lnog  Susanne
# 1987896  wL5jPrLRVCK_Pmo4lM1zpA      Isa
#
#                                                    friends  fans
# 0        NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267
# 1        ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...  3138
# 2        LuO3Bn4f3rlhyHIaNfTlnA, j9B4XdHUhDfTKVecyWQgyA...    52
# 3        enx1vVPnfdNUdPho6PH_wg, 4wOcvMLtU6a9Lslggq74Vg...    28
# 4        PBK4q9KEEBHhFvSXCUirIw, 3FWPpM7KU1gXeOM_ZbYMbA...     1
# ...                                                    ...   ...
# 1987892                                               None     0
# 1987893                                               None     0
# 1987894                                               None     0
# 1987895                                               None     0
# 1987896                                               None     0
#
# [1987897 rows x 4 columns]

# %%
unique_cities = df_b['city'].unique()

# Print the unique cities
for city in unique_cities:
    print(city)
# Out:
# Santa Barbara
# Affton
# Tucson
# Philadelphia
# Green Lane
# Ashland City
# Brentwood
# St. Petersburg
# Nashville
# Land O' Lakes
# Tampa Bay
# Indianapolis
# Clearwater
# Largo
# New Orleans
# Kenner
# Edmonton
# Reno
# Newtown
# White House
# Boise
# Paoli
# Ardmore
# Exton
# Wilmington
# Edwardsville
# Sparks
# Alton
# Cherry Hill
# Bala Cynwyd
# Springfield
# Belleville
# Carmel
# Tampa
# Kennett Square
# Plymouth Meeting
# Harvey
# West Chester
# Meridian
# Hudson
# Fernley
# Williamstown
# Pinellas Park
# Glenolden
# Wesley Chapel
# Fishers
# Burlington
# Troy
# Camden
# Plainfield
# Bensalem
# Maplewood
# Saint Louis
# Fairview Heights
# Oro Valley
# Treasure Island
# Southampton
# Chalfont
# Willow Grove
# Voorhees
# Tarpon Springs
# Blue Bell
# Metairie
# Woodbury
# Brownsburg
# Norristown
# Land O Lakes
# Greenwood
# Saint Petersburg
# Brookhaven
# Haverford
# Glenside
# Moorestown
# Madison
# Ewing
# Levittown
# Gloucester Township
# Aston
# Riverview
# Warrington
# Wyncote
# St. Louis
# Havertown
# Madeira Beach
# Lutz
# Langhorne
# King of Prussia
# Smithton
# Jenkintown
# New Port Richey
# Avon
# Normandy
# Wayne
# Franklin
# Tuscon
# Brandon
# Upper Pottsgrove
# Indianapolis city (balance)
# W. Berlin
# Tinicum Township
# Brentwood
# Town and Country
# South Reno
# Fairland
# Berlin Boro
# Winterthur
# gilbertsville
# Winchester
# Blooming Glen
# Maryland Height, MO
# Dellwood
# Safety Harbor,
# Oro valley
# wesley chapel
# Old Hickory, TN
# Wesley Chapel
# Ewing Twp
# Wesley Ccapel
# AB Edmonton
# Saint Louis,
# CHESTER HEIGHTS
# Indiana
# St Petersurg
# Tampa
# BOISE
# Gloucester
# Warminster
# Wilimington
# Green Valle
# Twin oaks
# Boutte
# Blackwood
# Mt  Juliet
# Madiera Beach
# Haverford
# Lincoln
# West Norriton
# Plainfiled
# CLIFTON HEIGHTS
# DELRAN
# St. Petersberg
# PINELLAS PARK
# Telford
# LANGHORNE
# St.Charles
# DOWNINGTOWN
# TRINITY
# Philly
# Saint Leo
# South Madison
# Alloway
# Cherry Hill Mall
# Tierre Verde
# Maran
# Stanton
# Fort Saskatchewan
# Philadelphia (Northeast Philly)
# MARLTON
# Landsale
# Foster Pond
# Newtown Sq.
# Costa Mesa
# Frederick
# UPPR BLCK EDY
# Lynnfield
# CONSHOHOCKEN
# Wycombe
# Santa  Barbara
# Swedeland
# Tennesse
# West Collingswood Heights
# Tampa,Fl
# Barto
# Boston
# N.Wales
# Creamery
# Sparks,
# Merion
# St Boise
# Sullivan
# goodlettsville
# Bel Ridge
# West Rockhill
# Haverton
# London Grove
# Salinas
# INpolis
# Clarksville
# Rutledge
# Delran Township
# Concord Village
# Carpinteria
# spring city
# Land O'lakes
# TUCSON AP
# Tampa,
# spring hill
# Johnson
# St. Leo
# Hurffville
# Kirklyn
# Overbrook
# New Tampa
# Edmonton City Centre
# Macdill Afb
# Charles
# Tortola
# Kng Of Prusia
# Newtown Sq
# Redington Shore
# Philadelphia
# Clearwater/ Countryside
# Pasco
# East Boise
# South Cherry Hill
# nolensville
# Williamsport
# Caln
# Fallsington
# Apopka
# TEMPLE TERR
# TAMPA AP
# RADNOR
# Safety Hatbor
# MANCHESTER
# St. Louis County
# West Nashville
# Santa Maria
# kenner
# Hollywood
# East Norriton
# Hernando Bch
# WILLOW GROVE
# Chattanooga
# Rancocas
# Bennington
# Middletown
# Philiadelphia
# Spark
# Bellefonte
# Town 'N' Country
# Newton
# S.Pasadena
# CHELTENHAM
# Lower Southampton
# Monchanin
# Wesley Chapel  FL
# Maryland Height
# MacDill AFB
# PLYMOUTH MTNG
# Monroe
# HENDERSONVILLE
# Reno Sparks
# St.  Charles
# Charlotte
# Key Largo
# Woodbury Hts.
# Mount Holly,
# Slidell
# Wales
# UPPER MORELAND
# Apollo beach

# %%
df_philadelphia_b = df_b[df_b['city']== 'Philadelphia']

# %%
df_r = read_chunks('review', ['review_id','user_id', 'business_id','stars'])

# %%
df_r
# Out:
#                       review_id                 user_id  \
# 0        KU_O5udG6zpxOg-VcAEodg  mh_-eMZ6K5RLWhZyISBhwA
# 1        BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 2        saUsX_uimxRlCVr67Z4Jig  8g_iMtfSiwikVnbP2etR0A
# 3        AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 4        Sx8TMOWLNuJBWer-0pcmoA  bcjbaE6dDog4jkNY91ncLQ
# ...                         ...                     ...
# 6990275  H0RIamZu0B0Ei0P4aeh3sQ  qskILQ3k0I_qcCMI-k6_QQ
# 6990276  shTPgbgdwTHSuU67mGCmZQ  Zo0th2m8Ez4gLSbHftiQvg
# 6990277  YNfNhgZlaaCO5Q_YJR4rEw  mm6E4FbCMwJmb7kPDZ5v2Q
# 6990278  i-I4ZOhoX70Nw5H0FwrQUA  YwAMC-jvZ1fvEUum6QkEkw
# 6990279  RwcKOdEuLRHNJe4M9-qpqg  6JehEvdoCvZPJ_XIxnzIIw
#
#                     business_id  stars
# 0        XQfwVwDr-v0ZS3_CbbE5Xw      3
# 1        7ATYjTIgM3jUlt4UM3IypQ      5
# 2        YjUWPpI6HXG530lwP-fb2A      3
# 3        kxX2SOes4o-D3ZQBkiMRfA      5
# 4        e4Vwtrqf-wpJfwesgvdgxQ      4
# ...                         ...    ...
# 6990275  jals67o91gcrD4DC81Vk6w      5
# 6990276  2vLksaMmSEcGbjI5gywpZA      5
# 6990277  R1khUUxidqfaJmcpmGd4aw      4
# 6990278  Rr9kKArrMhSLVE9a53q-aA      5
# 6990279  VAeEXLbEcI9Emt9KGYq9aA      3
#
# [6990280 rows x 4 columns]

# %%
philadelphia_business_ids = df_philadelphia_b['business_id']
df_r_philadelphia = df_r[df_r['business_id'].isin(philadelphia_business_ids)]
df_r_philadelphia
# Out:
#                       review_id                 user_id  \
# 1        BiTunyQ73aT9WBnpR9DZGw  OyoGAe7OKpv6SyGZT5g77Q
# 3        AqPFMleE6RsU23_auESxiA  _7bHUi9Uuf5__HHc_Q8guQ
# 5        JrIxlS1TzJ-iCu79ul40cQ  eUta8W_HdHMXPzLBBZhL1A
# 13       8JFGBuHMoiNDyfcxuWNtrA  smOvOajNG0lS4Pq7d8g4JQ
# 16       oyaMhzBSwfGgemSGuZCdwQ  Dd1jQj7S-BFGqRbApFzCFw
# ...                         ...                     ...
# 6990257  tWCi4N2qCil876BI2NDAZg  5d32aJe0a3_fSl3LIVYkWQ
# 6990260  nLjbVsETpqO17RbFcqskkA  am7-gkH_PDz598oTdYSD6A
# 6990263  99ylx-qPUSseITqBye2MpA  -AkziDwQ8hv2COTDBBUpig
# 6990265  KlHxcAifUF5zDKpJCBrRsw  7ziWZULyiZv2TesYNMFf4g
# 6990269  cACxcUY_AIsQKkpDRXuqnw  MCzlzlOw7IGbRAKVjJBPtg
#
#                     business_id  stars
# 1        7ATYjTIgM3jUlt4UM3IypQ      5
# 3        kxX2SOes4o-D3ZQBkiMRfA      5
# 5        04UD14gamNjLY0IDYVhHJg      1
# 13       RZtGWDLCAtuipwaZ-UfjmQ      4
# 16       YtSqYv1Q_pOltsVPSx54SA      5
# ...                         ...    ...
# 6990257  EmrOCT7fArKI0JI_XF6aaw      1
# 6990260  3gVSrS4kffGGZT8oXHsIcw      3
# 6990263  aunmz06iWvo3bd6MMHEbqg      3
# 6990265  qQO7ErS_RAN4Vs1uX0L55Q      4
# 6990269  fcGexL5VH5G2Xw0tRj9uOQ      3
#
# [967552 rows x 4 columns]

# %%
philadelphia_reviewed_user_ids = df_r_philadelphia['user_id'].unique()
df_u_philadelphia = df_u[df_u['user_id'].isin(philadelphia_reviewed_user_ids)]
# Extract friends' user IDs
friends_user_ids = df_u_philadelphia['friends'].explode().unique()

# Filter the user data frame again to include the users and their friends
df_u_philadelphia_and_friends = df_u[df_u['user_id'].isin(friends_user_ids)]

# %%
philadelphia_business_ids = df_philadelphia_b['business_id']
# Filter reviews for businesses in Philadelphia as you previously did
df_reviews_philadelphia = df_r[df_r['business_id'].isin(philadelphia_business_ids)]

# Extract unique user IDs who left reviews for businesses in Philadelphia
philadelphia_reviewed_user_ids = df_reviews_philadelphia['user_id'].unique()

# Filter the user data frame to include users who reviewed businesses in Philadelphia
df_users_philadelphia_reviewers = df_u[df_u['user_id'].isin(philadelphia_reviewed_user_ids)]

# Extract friends' user IDs from the filtered users
all_friends_user_ids = df_users_philadelphia_reviewers['friends'].str.split(', ').explode().unique()

# Filter the user data frame again to include the users and their friends
df_users_philadelphia_and_friends = df_u[df_u['user_id'].isin(all_friends_user_ids) | df_u['user_id'].isin(philadelphia_reviewed_user_ids)]

# %%
df_users_philadelphia_and_friends
# Out:
#                         user_id        name  \
# 0        qVc8ODYU5SZjKXVBgXdI7w      Walker
# 1        j14WgRoU_-2ZE1aw1dXrJg      Daniel
# 2        2WnXYQFK0hXEoTxPtV2zvg       Steph
# 3        SZDeASXq7o05mMNLshsdIA        Gwen
# 5        q_QQ5kBBwlCcbL1s4NVK3g        Jane
# ...                         ...         ...
# 1987832  iZ0puydkFQlaSQAXbGtv1g  Dr. Sylvia
# 1987834  XTWARBzLbiJKQ1JeJB9f3g      Sakina
# 1987859  K-BNvWUCWEGUuBirCU4mmg        Jodi
# 1987862  cu_xPeMTm8qsWShBIHJeuw       Susan
# 1987892  fB3jbHi3m0L2KgGOxBv6uw     Jerrold
#
#                                                    friends  fans
# 0        NSCy54eWehBJyZdG2iE84w, pe42u7DcCH2QmI81NX-8qA...   267
# 1        ueRPE0CX75ePGMqOFVj6IQ, 52oH4DrRvzzl8wh5UXyU0A...  3138
# 2        LuO3Bn4f3rlhyHIaNfTlnA, j9B4XdHUhDfTKVecyWQgyA...    52
# 3        enx1vVPnfdNUdPho6PH_wg, 4wOcvMLtU6a9Lslggq74Vg...    28
# 5        xBDpTUbai0DXrvxCe3X16Q, 7GPNBO496aecrjJfW6UWtg...  1357
# ...                                                    ...   ...
# 1987832                                               None     0
# 1987834                                               None     0
# 1987859                                               None     0
# 1987862                                               None     0
# 1987892                                               None     0
#
# [607181 rows x 4 columns]

# %%
# Extract user-user connections (e.g., friendships) from the 'friends' column
# Create a list of tuples where each tuple represents a friendship connection.
user_user_connections = [(user_id, friend_id) for user_id, friends in zip(df_u['user_id'], df_u['friends']) for friend_id in friends]

# Create an empty directed graph to represent the user-user network
user_graph = nx.DiGraph()

# Add nodes (users) to the graph
user_graph.add_nodes_from(user_data['user_id'])

# Add edges (friendships) to the graph
user_graph.add_edges_from(user_user_connections)

# Visualize the user-user network graph (optional)
plt.figure(figsize=(10, 8))
pos = nx.spring_layout(user_graph, k=0.05)  # Layout for the graph
nx.draw(user_graph, pos, with_labels=False, node_size=10)
plt.title('User-User Network Graph')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[86], line 3
#       1 # Extract user-user connections (e.g., friendships) from the 'friends' column
#       2 # Create a list of tuples where each tuple represents a friendship connection.
# ----> 3 user_user_connections = [(user_id, friend_id) for user_id, friends in zip(df_u['user_id'], df_u['friends']) for friend_id in friends]
#       5 # Create an empty directed graph to represent the user-user network
#
# Cell In[86], line 3, in <listcomp>(.0)
#       1 # Extract user-user connections (e.g., friendships) from the 'friends' column
#       2 # Create a list of tuples where each tuple represents a friendship connection.
# ----> 3 user_user_connections = [(user_id, friend_id) for user_id, friends in zip(df_u['user_id'], df_u['friends']) for friend_id in friends]
#       5 # Create an empty directed graph to represent the user-user network
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3547, in InteractiveShell.run_code(self, code_obj, result, async_)
#    3545 except:
#    3546     if result is not None:
# -> 3547         result.error_in_exec = sys.exc_info()[1]
#    3548     self.showtraceback(running_compiled_code=True)
#    3549 else:
#
# KeyboardInterrupt:
